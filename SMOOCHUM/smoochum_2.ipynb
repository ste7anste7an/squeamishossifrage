# %%
ncand=[ 30677, 38431, 76289, 106331, 116131, 145861, 195883, 201547, 227377, 269461, 406361, 457609, 476233, 506339, 543407, 578563, 666683, 699967, 752881, 757927, 773567, 817303, 821263, 824179, 830329, 865231, 970061, 996431, 1015403, 1019059, 1021651, 1021777, 1044437]
cand=[17623, 25643, 63761, 94687, 104527, 121591, 147347, 187687, 213307, 217691, 228509, 409777, 412001, 420241, 449363, 484787, 569197, 619807, 622663, 631619, 645787, 658433, 666461, 684569, 717841, 762721, 775259, 775933, 776029, 819431, 836939, 1032307, 1043849]
ncand=

# %%
cand
# Out:
# [17623,
#  25643,
#  63761,
#  94687,
#  104527,
#  121591,
#  147347,
#  187687,
#  213307,
#  217691,
#  228509,
#  409777,
#  412001,
#  420241,
#  449363,
#  484787,
#  569197,
#  619807,
#  622663,
#  631619,
#  645787,
#  658433,
#  666461,
#  684569,
#  717841,
#  762721,
#  775259,
#  775933,
#  776029,
#  819431,
#  836939,
#  1032307,
#  1043849]

# %%
def is_square(apositiveint):
  x = apositiveint // 2
  seen = set([x])
  while x * x != apositiveint:
    x = (x + (apositiveint // x)) // 2
    if x in seen: return False
    seen.add(x)
  return True

# %%
c=[]
import itertools
i=100000
j=0
for factors in itertools.combinations(cand,24):
    i-=1
    if i==0:
        i=100000
        j+=1
        print(j*100000)
    backd=2
    for f in factors:
        backd*=f
    if is_square(backd**2+4*ncand):
        print(backd)
        c.append(backd)
# Out:
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# 1200000
# 1300000

# %%
c
# Out:
# [1822127364722206264538550901959902639418477491551528669852926892847193423762404887880541297237663852783234201411629106958862481860102]

# %%
from Crypto.PublicKey import RSA
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-b6fe4d249eef> in <module>
# ----> 1 from Crypto.PublicKey import RSA
#
# ModuleNotFoundError: No module named 'Crypto'

# %%
# !pip3 install pycrypto
# Out:
# ...
#   Using cached pycrypto-2.6.1.tar.gz (446 kB)
# ...
#   Running setup.py clean for pycrypto
# Failed to build pycrypto
# ...
#     Running setup.py install for pycrypto: started
#     Running setup.py install for pycrypto: finished with status 'error'
#   ERROR: Command errored out with exit status 1:
#    command: 'c:\program files\python38\python.exe' -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\decimapc\\AppData\\Local\\Temp\\pip-install-t7wlohfw\\pycrypto\\setup.py'"'"'; __file__='"'"'C:\\Users\\decimapc\\AppData\\Local\\Temp\\pip-install-t7wlohfw\\pycrypto\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d 'C:\Users\decimapc\AppData\Local\Temp\pip-wheel-x2end4lb'
#        cwd: C:\Users\decimapc\AppData\Local\Temp\pip-install-t7wlohfw\pycrypto\
#   Complete output (183 lines):
#   running bdist_wheel
#   running build
# ...
